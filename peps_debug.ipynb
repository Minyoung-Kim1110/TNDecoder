# %%
from debug_where_detector_loss_emerges import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
audit_where_loss_emerges(
    distance=5,
    p=0.01,
    shots=100,
    memory_basis="x",
    rounds=3,
    target_t=1,
    only_nontrivial_obs=True,
    max_cases=10,
)

print("\n" + "=" * 100 + "\n")

audit_where_loss_emerges(
    distance=5,
    p=0.01,
    shots=100,
    memory_basis="z",
    rounds=3,
    target_t=1,
    only_nontrivial_obs=True,
    max_cases=10,
)
# Out:
# ...
# WHERE DETECTOR-MAPPING LOSS EMERGES
# ...
# distance=5, p=0.01, shots=100, memory_basis=x, rounds=3, target_t=1, only_nontrivial_obs=True
# num detectors total          : 120
# num detectors on target_t    : 40
# num x_checks on target_t     : 20
# num z_checks on target_t     : 20
# detector count by time       : {0: 20, 1: 40, 2: 40, 3: 20}
#
# ----------------------------------------------------------------------------------------------------
# shot 12
#   observable_flip                 : 1
#   fired total                     : 7
#   fired on target_t               : 4
#   fired dropped before split      : 3
#   fired represented in sX/sZ      : 4
#   fired on target_t but lost      : 0
#   current sample sX weight        : 2
#   current sample sZ weight        : 2
#   rebuilt sX weight               : 2
#   rebuilt sZ weight               : 2
#   dense shape                     : (9, 9)
#   fired count by time             : {0: 1, 1: 4, 2: 2}
#
# Fired detectors: 7
# ...
